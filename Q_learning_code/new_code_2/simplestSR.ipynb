# %%
    def init_TrueValue(self, i):
        if i == 0:
            return 20
        else:
            return 70

    
    def init_Prices(self):
        
        pricesArray = np.zeros((2, 2))
        for vb in range(0, 2):
            for vs in range(0, 2):
                
                # (vs-200) - (130-cb) + 165
                
                pricesArray[vb][vs] = 0.2*vb
                
        return pricesArray

            Profits[0][i] = [pb_na, ps_na]
            Penalty[0][i] = [penalb,penals]
        #No mechanism
            
            if vb == vs and vb==1:
                # if all report coincide at 70
                
                # profit for buyer: true value - price 
                pb = self.trueValue - self.Prices[vb][vs]
                
                # profit for seller: price - true cost 
                ps = self.Prices[vb][vs]  
            elif:
                vb == vs and vb==0:
                # if all report coincide at 20
                # no trade and no penalty
                pb = 0
                ps =0
            else:
                #no agreement no trade and both players are penalized
                penalb = - 300
                penals = -300
        
                    

            Profits[1][i] = [pb, ps]
            Penalty[1][i] = [penalb,penals]
            

        return Profits,Penalty
# Out:
#   Cell In[1], line 20
#     Profits[0][i] = [pb_na, ps_na]
#     ^
# IndentationError: unexpected indent

# %%
 def init_Profits(self):
        Profits = np.zeros((2, self.numActions, self.numPlayers))
        Actions = np.zeros((self.numActions, 6))
        
        Penalty = np.zeros((2, self.numActions, self.numPlayers))
        
        for i in range(self.numActions):
            
            b = int(self.indexActions[i][0])
            s = int(self.indexActions[i][1])
            
            vb, vb_a = self.buyerActions[b]
            vs = self.sellerActions[s]
            penalb = 0
            penals = 0
            
            Actions[i] = vb, vb_a, vs
        

    
    def init_Prices(self):
        
        pricesArray = np.zeros((2, 2))
        for vb in range(0, 2):
            for vs in range(0, 2):
                
                # (vs-200) - (130-cb) + 165
                
                pricesArray[vb][vs] = 0.2*vb
                
        return pricesArray

            Profits[0][i] = [pb_na, ps_na]
            Penalty[0][i] = [penalb,penals]
        #SR mechanism
            
            if vb == vs and vb==1:
                # if all report coincide at 70
                
                # profit for buyer: true value - price 
                pb = self.trueValue - self.Prices[vb][vs]
                
                # profit for seller: price - true cost 
                ps = self.Prices[vb][vs]  
            elif:
                vb == vs and vb==0:
                # if all report coincide at 20
                # no trade and no penalty
                pb = 0
                ps =0
            else:
                #no agreement no trade and only buyer is penalized
                penalb = - 300
                if vs=vb_a
                 penals = self.reward
                    
                else:
                    penals =self.penalty
                
        
                    

            Profits[1][i] = [pb, ps]
            Penalty[1][i] = [penalb,penals]
            

        return Profits,Penalty
# Out:
#   File <tokenize>:21
#     def init_Prices(self):
#     ^
# IndentationError: unindent does not match any outer indentation level
